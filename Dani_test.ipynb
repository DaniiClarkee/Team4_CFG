# %%
import pandas as pd
df_raw = pd.read_csv("data.csv", index_col=[0])

# %%
df_raw.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
df_raw['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
col_names = df_raw.columns
num_data = df_raw.shape[0]
for c in col_names:
    num_non = df_raw[c].isin([" ?"]).sum()
    if num_non > 0:
        print (c)
        print (num_non)
        print ("{0:.2f}%".format(float(num_non) / num_data * 100))
        print ("\n")

# %%
df_raw = df_raw[df_raw["diagnosis"] != " ?"]

# %%
df_raw.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
one_hot_df = pd.get_dummies(df_raw, drop_first=True)

# %%
df_raw.shape
# Out:
# (569, 32)

# %%
one_hot_df.shape
# Out:
# (569, 32)

# %%
one_hot_df.head(15)
# Out:
#           radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302          17.99         10.38          122.80     1001.0
# 842517          20.57         17.77          132.90     1326.0
# 84300903        19.69         21.25          130.00     1203.0
# 84348301        11.42         20.38           77.58      386.1
# 84358402        20.29         14.34          135.10     1297.0
# 843786          12.45         15.70           82.57      477.1
# 844359          18.25         19.98          119.60     1040.0
# 84458202        13.71         20.83           90.20      577.9
# 844981          13.00         21.82           87.50      519.8
# 84501001        12.46         24.04           83.97      475.9
# 845636          16.02         23.24          102.70      797.8
# 84610002        15.78         17.89          103.60      781.0
# 846226          19.17         24.80          132.40     1123.0
# 846381          15.85         23.95          103.70      782.7
# ...
